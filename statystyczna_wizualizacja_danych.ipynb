# %% [markdown]
# <a href="https://colab.research.google.com/github/mateuszStanislawski/projekt_MR/blob/master/statystyczna_wizualizacja_danych.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns 
import pandas as pd
import numpy as np

# %%
x = np.linspace(0, 20, 100)
y = np.random.randn(100,4)
y = np.cumsum(y, axis = 0)

# %%
plt.plot(x, y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f9a59a84b70>,
#  <matplotlib.lines.Line2D at 0x7f9a59a84cf8>,
#  <matplotlib.lines.Line2D at 0x7f9a59a84e48>,
#  <matplotlib.lines.Line2D at 0x7f9a59a84f98>]

# %%
sns.set()
plt.plot(x,y)
# Out:
# [<matplotlib.lines.Line2D at 0x7f9a595dec18>,
#  <matplotlib.lines.Line2D at 0x7f9a595deda0>,
#  <matplotlib.lines.Line2D at 0x7f9a595def28>,
#  <matplotlib.lines.Line2D at 0x7f9a595eb0f0>]

# %%
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include=['category'])
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
sns.relplot(data = df, x = 'total_bill', y = 'tip')

# %%
sns.set(style = 'darkgrid', palette = 'deep', font_scale=1)

# %%
sns.relplot(data = df, x = 'total_bill', y = 'tip')

# %%
sns.set(palette = 'pastel', font_scale=1)
sns.relplot(data = df, x = 'total_bill', y = 'tip', size = 'sex', hue = 'sex',
            style = 'sex')

# %%
sns.relplot(data = df, x = 'total_bill', y = 'tip', size = 'size', hue = 'size',
            style = 'size', col = 'time', row = "smoker")

# %%
df = sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data = df, x ="timepoint", y = 'signal', kind = 'line')

# %%
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
df.timepoint.value_counts()
# Out:
# 18    56
# 8     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 9     56
# 17    56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 0     56
# Name: timepoint, dtype: int64

# %%
df.describe()
# Out:
#          timepoint       signal
# count  1064.000000  1064.000000
# mean      9.000000     0.003540
# std       5.479801     0.093930
# min       0.000000    -0.255486
# 25%       4.000000    -0.046070
# 50%       9.000000    -0.013653
# 75%      14.000000     0.024293
# max      18.000000     0.564985

# %%
df.groupby('timepoint').agg('mean').plot()

# %%
sns.relplot(data = df, x ='timepoint', y ='signal', hue = 'event', kind = 'line',style = 'event', markers=True,
            col = 'region')

# %%
sns.relplot(data = df, x ='timepoint', y ='signal', hue = 'event', kind = 'line',style = 'event', markers=True,
            col = 'subject', col_wrap = 4)

# %%
 df = sns.load_dataset('tips')
 df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set(style='ticks', palette = 'pastel')
sns.catplot(data = df, x = 'day', y='total_bill')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'swarm')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'box')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'violin')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'boxen')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'point')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'bar')

# %%
sns.catplot(data = df, x = 'day', kind = 'count')

# %%
sns.catplot(data = df, x = 'day', y='total_bill', kind = 'swarm', hue = 'sex')

# %%
sns.catplot(data = df.query("day == ['Fri','Sat', 'Sun']"), x = 'day', y='total_bill', kind = 'swarm', hue = 'sex')

# %%
##TITANIC DATA
df = sns.load_dataset('titanic')
df.head(3)
# Out:
#    survived  pclass     sex   age  ...  deck  embark_town  alive  alone
# 0         0       3    male  22.0  ...   NaN  Southampton     no  False
# 1         1       1  female  38.0  ...     C    Cherbourg    yes  False
# 2         1       3  female  26.0  ...   NaN  Southampton    yes   True
#
# [3 rows x 15 columns]

# %%
sns.catplot(data = df, x = 'sex', y='survived', kind = 'bar')

# %%
sns.catplot(data = df, x = 'sex', y='survived', kind = 'bar', hue='class')

# %%
sns.catplot(data = df, y = 'deck', kind='count', palette = 'Blues')

# %%
sns.set(style = 'darkgrid')
df = np.random.multivariate_normal(mean = [0,1], cov=[(1, -0.4),(-0.4,1)], size = 200)
df = pd.DataFrame(df, columns=['x','y'])
df.head(3)
# Out:
#           x         y
# 0  0.521745  1.626659
# 1  0.253129  0.125727
# 2 -0.415798  0.726361

# %%
df.describe()
# Out:
#                 x           y
# count  200.000000  200.000000
# mean    -0.184482    1.106912
# std      0.950609    0.991873
# min     -3.257864   -1.635211
# 25%     -0.839163    0.376272
# 50%     -0.185383    1.189550
# 75%      0.511813    1.722343
# max      1.901303    3.938032

# %%
sns.jointplot(data = df, x='x', y = 'y')

# %%
sns.jointplot(data = df, x='x', y = 'y', kind = 'hex')

# %%
sns.jointplot(data = df, x='x', y = 'y', kind = 'kde')

# %%
g = sns.jointplot(data = df, x='x', y = 'y', kind = 'kde', n_levels = 15 , cmap = 'viridis')
g.plot_joint(plt.scatter, c ='w', s = 30, marker = '+')

# %%
df = sns.load_dataset('iris')
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=df, hue = 'species')

# %%
g = sns.PairGrid(df, hue='species')
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 6)

# %%
uni = np.random.randn(100, 100)
sns.heatmap(uni)

# %%
df = sns.load_dataset('flights')
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df.describe()
# Out:
#               year  passengers
# count   144.000000  144.000000
# mean   1954.500000  280.298611
# std       3.464102  119.966317
# min    1949.000000  104.000000
# 25%    1951.750000  180.000000
# 50%    1954.500000  265.500000
# 75%    1957.250000  360.500000
# max    1960.000000  622.000000

# %%
df = df.pivot(index = 'month', columns = 'year', values = 'passengers')

# %%
sns.heatmap(df)

# %%
sns.heatmap(df, annot = True, fmt = 'd', cmap = 'viridis')
